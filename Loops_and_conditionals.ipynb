# %%
#4.1
secret = 1
guess = 7
if guess <= secret:
    print("to low")
elif guess >= secret:
    print("to high")
elif guess == secret:
    print("just right")
else:
    print("invalid")
# Out:
# to high

# %%
#4.2
green = True
small = False
if green:
    if small:
        print("its a pea")
    else:
        print("Watermelon")
else:
    if green:
        print("cherry")
    else:
        print("pumpkin")

# %%
#6.1

for number in [3, 2, 1, 0]:
    print(number)

# %%
#6.2
number = 1
guess_me = 7

while True:
    if number <= guess_me:
        print("to low")
        print(number)
        break
    elif number == guess_me:
        print("found it")
        print(number)
        break
    else:
        print("oops")

# %%
#6.2
number = 1
guess_me = 7
while True:
    if number <= guess_me:
        print("to Low")
    elif number >= guess_me:
        print("to high")
    elif number == guess_me:
        print("found it")
        break
    else:
        print("oops")
        break

# %%
#6.3
guess_me = 5

for number in range(10):
    if number <= guess_me:
        print("to low")
        print(number)
    elif number == guess_me:
        print("found it")
        print(number)
    else:
        print("oops")
